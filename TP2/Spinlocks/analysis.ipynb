# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(context = 'paper', style='whitegrid', font_scale = 1.4)

# %%
path = 'report.csv'
data = pd.read_csv(path, names=['N','K','Tempo'])
data
# Out:
#              N    K     Tempo
# 0     10000000    1  0.011598
# 1     10000000    2  0.011841
# 2     10000000    4  0.009500
# 3     10000000    8  0.008643
# 4     10000000   16  0.012831
# 5     10000000   32  0.007764
# 6     10000000   64  0.011726
# 7     10000000  128  0.013307
# 8     10000000  256  0.016592
# 9    100000000    1  0.172881
# 10   100000000    2  0.167940
# 11   100000000    4  0.249314
# 12   100000000    8  0.383290
# 13   100000000   16  0.354340
# 14   100000000   32  0.343773
# 15   100000000   64  0.199664
# 16   100000000  128  0.155813
# 17   100000000  256  0.150635
# 18  1000000000    1  1.854100
# 19  1000000000    2  2.448810
# 20  1000000000    4  3.922300
# 21  1000000000    8  6.488840
# 22  1000000000   16  6.364780
# 23  1000000000   32  6.412890
# 24  1000000000   64  6.343820
# 25  1000000000  128  6.129490
# 26  1000000000  256  5.504260

# %%
fig = plt.figure(figsize=(12,6))
fig.suptitle('Número de threads X Tempo', fontsize=20)
plt.xlabel('K', fontsize=15)
plt.ylabel('Tempo (s)', fontsize=15)
sns.lineplot(
  data = data,
  x = "K",
  y = "Tempo",
  hue = "N",
  linewidth = 3,
  palette = ["blue", "red", "green"]
)
plt.show()
